# %% [markdown]
# <a href="https://colab.research.google.com/github/SantiagoTorresM/dipoda/blob/main/An%C3%A1lisis_de_bibliotecas_en_universidades_p%C3%BAblicas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
vc_edi = pd.read_csv('/content/1 Observación en campo a nivel de edificaciones 21dic.txt', sep = '|', encoding='utf-8')
vc_edi.head()
# Out:
#    CodUniv  Siglas                                               Univ  \
# 0     75.0  UNAMAD    UNIVERSIDAD NACIONAL AMAZÓNICA DE MADRE DE DIOS
# 1     89.0  UNAJMA           UNIVERSIDAD NACIONAL JOSÉ MARÍA ARGUEDAS
# 2     33.0  UNASAM    UNIVERSIDAD NACIONAL SANTIAGO ANTÚNEZ DE MAYOLO
# 3     25.0     UNE  UNIVERSIDAD NACIONAL DE EDUCACIÓN ENRIQUE GUZM...
# 4      6.0     UNI                 UNIVERSIDAD NACIONAL DE INGENIERÍA
#
#     CodEdif CodLoc              ID            Reg         Prov            Dis  \
# 0  SL01ED01   SL01  UNAMADSL01ED01  MADRE DE DIOS    TAMBOPATA      TAMBOPATA
# 1  SL01ED08   SL01  UNAJMASL01ED08       APURIMAC  ANDAHUAYLAS   SAN JERONIMO
# 2  SL01ED10   SL01  UNASAMSL01ED10         ANCASH       HUARAZ  INDEPENDENCIA
# 3  SL01ED55   SL01     UNESL01ED55           LIMA         LIMA     LURIGANCHO
# 4  SL01ED93   SL01     UNISL01ED93           LIMA         LIMA          RIMAC
#
#    Ubigeo  ...  P25_4X  P25_5X P25X   IND14      IND15   IND20   IND21  \
# ...

# %%
vc_amb = pd.read_csv('/content/2 Observación en campo a nivel de ambientes 21dic.txt', sep = '|', encoding='utf-8')
vc_amb.head()
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (17,30,64,65,66,67,68,69,74,75,76,77,78,79,80,81,82,83,84,85,86,87,122,123,124,125,126,127,128,129,130,136,137,138,139,140,154,155,156,157,158,159,160,161,177,178,179,180,181,189,191,192,198,199,200,201,202,203,204,205,206,207,208,209,210,211,212,215) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    CodUniv   CodEdif Siglas                                      Univ CodLoc  \
# 0      4.0  SL01ED16    UNT          UNIVERSIDAD NACIONAL DE TRUJILLO   SL01
# 1      4.0  SL01ED23    UNT          UNIVERSIDAD NACIONAL DE TRUJILLO   SL01
# 2      5.0  SL01ED49   UNSA       UNIVERSIDAD NACIONAL DE SAN AGUSTÍN   SL01
# 3      6.0  SL01ED01    UNI        UNIVERSIDAD NACIONAL DE INGENIERÍA   SL01
# 4     10.0  SL01ED13   UNCP  UNIVERSIDAD NACIONAL DEL CENTRO DEL PERÚ   SL01
#
# ...

# %%
si_bib_inf = pd.read_csv('/content/9 Solicitud de información a nivel biblioteca.txt', sep = '|', encoding='utf-8')
si_bib_inf.head()
# Out:
#                   ID  CodUniv Siglas  \
# 0   UNSASL03ED14BC04      5.0   UNSA
# 1   UNCPSL01ED07BC01     10.0   UNCP
# 2   UNSASL02ED32BC03      5.0   UNSA
# 3    UNISL01ED65BE11      6.0    UNI
# 4  UNALMSL01ED01BC01      7.0  UNALM
#
#                                               Univ CodLoc  \
# 0  UNIVERSIDAD NACIONAL DE SAN AGUSTÍN DE AREQUIPA   SL03
# 1         UNIVERSIDAD NACIONAL DEL CENTRO DEL PERÚ   SL01
# 2  UNIVERSIDAD NACIONAL DE SAN AGUSTÍN DE AREQUIPA   SL02
# 3               UNIVERSIDAD NACIONAL DE INGENIERÍA   SL01
# 4           UNIVERSIDAD NACIONAL AGRARIA LA MOLINA   SL01
#
#                                     Local   CodEdif  \
# 0            AREA DE CIENCIAS DE LA SALUD  SL03ED14
# 1                    CIUDAD UNIVERSITARIA  SL01ED07
# 2               AREA DE CIENCIAS SOCIALES  SL02ED32
# 3       UNIVERSIDAD NACIONAL DE INGENERIA  SL01ED65
# 4  UNIVERSIDAD NACIONAL AGRARIA LA MOLINA  SL01ED01
#
# ...

# %%
si_bib_equi = pd.read_csv('/content/16 Solicitud de equipamiento bibliotecas.txt', sep = '|', encoding='utf-8')
si_bib_equi.head()
# Out:
#                          ID  CodUniv    Siglas  \
# 0       UNISL01ED01BC01EQU2      6.0       UNI
# 1  UNTUMBESSL01ED27BC01EQU1     41.0  UNTUMBES
# 2    UNASAMSL01ED11BC01EQU2     33.0    UNASAM
# 3     UNDQTSL05ED01BC03EQU3    992.0     UNDQT
# 4       UNHSL01ED08BC01EQU8     51.0       UNH
#
#                                               Univ CodLoc  \
# 0               UNIVERSIDAD NACIONAL DE INGENIERÍA   SL01
# 1                   UNIVERSIDAD NACIONAL DE TUMBES   SL01
# 2  UNIVERSIDAD NACIONAL SANTIAGO ANTÚNEZ DE MAYOLO   SL01
# 3           UNIVERSIDAD NACIONAL DIEGO QUISPE TITO   SL05
# 4             UNIVERSIDAD NACIONAL DE HUANCAVELICA   SL01
#
#                                                Local   CodEdif  \
# 0                  UNIVERSIDAD NACIONAL DE INGENERIA  SL01ED01
# 1                               CIUDAD UNIVERSITARIA  SL01ED27
# 2                               CIUDAD UNIVERSITARIA  SL01ED11
# 3  SEDE DESCONCENTRADA DE LA UNIVERSIDAD NACIONAL...  SL05ED01
# ...

# %%
er_bib = pd.read_csv('/content/5 Biblioteca.txt', sep = '|', encoding='utf-8')
er_bib.head()
# Out:
#                    ID  CodUniv  Siglas  \
# 0     UNTSL01ED26BE01      4.0     UNT
# 1     UNISL03ED01BE16      6.0     UNI
# 2     UNISL01ED06BE03      6.0     UNI
# 3     UNISL03ED02BE17      6.0     UNI
# 4  UNSAACSL01ED23BE20      3.0  UNSAAC
#
#                                                 Univ CodLoc   CodEdif  \
# 0                   UNIVERSIDAD NACIONAL DE TRUJILLO   SL01  SL01ED26
# 1                 UNIVERSIDAD NACIONAL DE INGENIERIA   SL03  SL03ED01
# 2                 UNIVERSIDAD NACIONAL DE INGENIERIA   SL01  SL01ED06
# 3                 UNIVERSIDAD NACIONAL DE INGENIERIA   SL03  SL03ED02
# 4  UNIVERSIDAD NACIONAL DE SAN ANTONIO ABAD DEL C...   SL01  SL01ED23
#
#          CodBib                                            NombBib  TipoBib  \
# 0  SL01ED26BE01  BIBLIOTECA DE DERECHO Y CIENCIAS POLÍTICAS DE ...      2.0
# 1  SL03ED01BE16                                         BIBLIOTECA      2.0
# ...

# %%
#
bars = ('Especializada','Central')
x_pos = np.arange(len(bars))
er_bib.TipoBib.value_counts().plot(kind='bar')
plt.xticks(x_pos, bars)
plt.xlabel('Tipo de biblioteca', labelpad=14)
plt.ylabel('Cantidad', labelpad=14)
plt.title('Bibliotecas en universidades públicas según tipo', y=1.02)
plt.show;
